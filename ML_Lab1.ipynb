# %% [markdown]
# # Lab 1 Part 3:     Linear models
#
# ---
#
# ![image.png](data:image/png;base64,...)
#
# ---

# %% [markdown]
# Note: Use the last 2 labs as resources for this lab 🆗

# %% [markdown]
# ## Step 1: Define the Problem
# The **NO2** dataset contains 500 measurement of pollution caused by cars. **The goal is to predict** the concentration of no2 from data about traffic and atmospheric conditions. The predictive variables include the number of cars per hour, temperature, wind, and time of day.

# %% [markdown]
# ## Step 2: Collect Data

# %%
# !pip install openml
# Out:
# Requirement already satisfied: openml in c:\users\jouri\anaconda3\lib\site-packages (0.15.1)
# Requirement already satisfied: liac-arff>=2.4.0 in c:\users\jouri\anaconda3\lib\site-packages (from openml) (2.5.0)
# Requirement already satisfied: xmltodict in c:\users\jouri\anaconda3\lib\site-packages (from openml) (0.14.2)
# Requirement already satisfied: requests in c:\users\jouri\anaconda3\lib\site-packages (from openml) (2.32.2)
# Requirement already satisfied: scikit-learn>=0.18 in c:\users\jouri\anaconda3\lib\site-packages (from openml) (1.4.2)
# Requirement already satisfied: python-dateutil in c:\users\jouri\anaconda3\lib\site-packages (from openml) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.0.0 in c:\users\jouri\anaconda3\lib\site-packages (from openml) (2.2.2)
# Requirement already satisfied: scipy>=0.13.3 in c:\users\jouri\anaconda3\lib\site-packages (from openml) (1.13.1)
# Requirement already satisfied: numpy>=1.6.2 in c:\users\jouri\anaconda3\lib\site-packages (from openml) (1.26.4)
# Requirement already satisfied: minio in c:\users\jouri\anaconda3\lib\site-packages (from openml) (7.2.15)
# Requirement already satisfied: pyarrow in c:\users\jouri\anaconda3\lib\site-packages (from openml) (14.0.2)
# Requirement already satisfied: tqdm in c:\users\jouri\anaconda3\lib\site-packages (from openml) (4.66.4)
# Requirement already satisfied: packaging in c:\users\jouri\anaconda3\lib\site-packages (from openml) (23.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jouri\anaconda3\lib\site-packages (from pandas>=1.0.0->openml) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jouri\anaconda3\lib\site-packages (from pandas>=1.0.0->openml) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\jouri\anaconda3\lib\site-packages (from python-dateutil->openml) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\jouri\anaconda3\lib\site-packages (from scikit-learn>=0.18->openml) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\jouri\anaconda3\lib\site-packages (from scikit-learn>=0.18->openml) (2.2.0)
# Requirement already satisfied: certifi in c:\users\jouri\anaconda3\lib\site-packages (from minio->openml) (2024.8.30)
# Requirement already satisfied: urllib3 in c:\users\jouri\anaconda3\lib\site-packages (from minio->openml) (2.2.2)
# Requirement already satisfied: argon2-cffi in c:\users\jouri\anaconda3\lib\site-packages (from minio->openml) (21.3.0)
# Requirement already satisfied: pycryptodome in c:\users\jouri\anaconda3\lib\site-packages (from minio->openml) (3.21.0)
# Requirement already satisfied: typing-extensions in c:\users\jouri\anaconda3\lib\site-packages (from minio->openml) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jouri\anaconda3\lib\site-packages (from requests->openml) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jouri\anaconda3\lib\site-packages (from requests->openml) (3.7)
# Requirement already satisfied: colorama in c:\users\jouri\anaconda3\lib\site-packages (from tqdm->openml) (0.4.6)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\jouri\anaconda3\lib\site-packages (from argon2-cffi->minio->openml) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\jouri\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->minio->openml) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\jouri\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->minio->openml) (2.21)

# %%
# General imports
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import openml as oml
from matplotlib import cm
import sys
import os

# %%
# Hide convergence warning for now
import warnings
from sklearn.exceptions import ConvergenceWarning
warnings.filterwarnings("ignore", category=ConvergenceWarning)

# Hiding all warnings. Not recommended, just for compilation.
if not sys.warnoptions:
    warnings.simplefilter("ignore")
    os.environ["PYTHONWARNINGS"] = "ignore"

# %%
# Download NO2 data. Takes a while the first time.
no2 = oml.datasets.get_dataset(547)
X, y, _, _ = no2.get_data(target=no2.default_target_attribute);
attribute_names = list(X)

# %% [markdown]
# ### **Question**: We said that the dataset, using Scikit-learn, can be imported from multiple options such as small dataset loading (toy data), data fetchers, and synthetic data generation. Which option is this one?

# %% [markdown]
# Your Answer:

# %% [markdown]
# ## Step 3: Exploratory Data Analysis
# Understand the data
#
# We can use pandas to quickly visualize the data. If you are new to pandas, take some time to understand the code.
#
# We’ll remove the ‘day’ feature to focus on the non-temporal aspects of this interaction. We are not aiming to predict future levels, and even if we would it would require special treatment (e.g. different train-test splits). There also doesn’t seem to be a long term trend in the data, even though there are clear periodic trends in temperature.

# %%
df = pd.DataFrame(X, columns=attribute_names).join(pd.DataFrame(list(y),columns=['target']))
df = df.sort_values(['day','hour_of_day']).drop('day',axis=1)
df.head()
# Out:
#      cars_per_hour  temperature_at_2m  wind_speed  temperature_diff_2m_25m  \
# 42         7.64300                8.5         4.3                     -0.2
# 20         7.75061                8.2         4.5                      0.2
# 255        8.12415                5.2         2.8                      0.3
# 488        7.64108                6.7         2.3                     -0.4
# 94         8.31630                6.3         1.2                      1.3
#
#      wind_direction  hour_of_day   target
# 42            322.0           13  3.22287
# 20            307.0           14  3.15274
# 255           209.0            8  4.19570
# 488           247.0           10  3.98155
# 94            265.0           17  4.14155

# %% [markdown]
# ### Question: What other Pandas techniques can you use to understand the data? Use 5 methods to explore your data.

# %%
#1 
df.shape
# Out:
# (500, 7)

# %%
#2
df.describe()
# Out:
#        cars_per_hour  temperature_at_2m  wind_speed  temperature_diff_2m_25m  \
# count     500.000000         500.000000  500.000000               500.000000
# mean        6.973342           0.847400    3.056000                 0.149400
# std         1.087166           6.524636    1.784172                 1.065237
# min         4.127130         -18.600000    0.300000                -5.400000
# 25%         6.175842          -3.900000    1.675000                -0.200000
# 50%         7.425360           1.100000    2.800000                 0.000000
# 75%         7.793175           4.900000    4.200000                 0.600000
# max         8.348540          21.100000    9.900000                 4.300000
#
#        wind_direction  hour_of_day      target
# count      500.000000   500.000000  500.000000
# mean       143.370400    12.382000    3.698368
# std         86.510213     6.802693    0.750597
# min          2.000000     1.000000    1.223780
# 25%         72.000000     6.000000    3.213862
# 50%         97.000000    12.500000    3.848020
# 75%        220.000000    18.000000    4.216930
# max        359.000000    24.000000    6.395090

# %%
#3
df.values
# Out:
# array([[  7.643  ,   8.5    ,   4.3    , ..., 322.     ,  13.     ,
#           3.22287],
#        [  7.75061,   8.2    ,   4.5    , ..., 307.     ,  14.     ,
#           3.15274],
#        [  8.12415,   5.2    ,   2.8    , ..., 209.     ,   8.     ,
#           4.1957 ],
#        ...,
#        [  7.61283,  20.3    ,   4.2    , ..., 278.9    ,  10.     ,
#           3.48431],
#        [  7.76853,  21.1    ,   4.5    , ..., 285.1    ,  11.     ,
#           2.89037],
#        [  5.50939,  10.3    ,   2.2    , ...,  37.4    ,   4.     ,
#           3.32863]])

# %%
#4
df.size
# Out:
# 3500

# %%
#5
df.value_counts()
# Out:
# cars_per_hour  temperature_at_2m  wind_speed  temperature_diff_2m_25m  wind_direction  hour_of_day  target
# 4.12713         2.5               5.6          0.3                     213.5           3            2.79728    1
# 7.68064         0.3               1.3          1.4                     221.8           19           4.47050    1
# 7.71244         7.5               1.8         -2.7                     273.9           12           4.23411    1
#                -9.9               2.7          0.7                     78.0            21           4.19117    1
# 7.71065         15.8              3.7         -0.3                     136.4           16           3.54385    1
#                                                                                                               ..
# 6.61740         6.5               4.1          0.0                     88.0            24           2.73437    1
#                 2.2               3.9          0.0                     67.0            6            3.39786    1
# 6.61607         0.1               0.4          2.0                     122.3           22           4.24850    1
# 6.60800         7.2               0.6          1.3                     191.4           24           3.92986    1
# 8.34854         2.7               7.7          0.1                     219.0           17           3.81551    1
# Name: count, Length: 500, dtype: int64

# %% [markdown]
# ## Quick Visualization

# %%
df.plot(use_index=False,figsize=(20,5),cmap=cm.get_cmap('brg'));
X = X.drop('day',axis=1)

# %% [markdown]
# If we plot the data, ordered by time of measurement, we can see that the wind direction (measured in angular degrees) is scaled very differently from the other features. Let’s now zoom in to the other measures:

# %%
df.drop('wind_direction',axis=1).plot(use_index=False,figsize=(20,5),cmap=cm.get_cmap('brg'));

# %% [markdown]
# We can see that the target (
#  levels) seem to be correlated to the number of cars per hour, which makes sense because cars produce
# . Other influences (air temperature differences and wind) seem to have a more complex and subtle effect. Let’s try to model these using linear regression models.

# %% [markdown]
# # Exercise 1: Model benchmark
# It is clear that concentrations depend on a combination of these features, so we will now try to learn this complex relationship. We first evaluate a range of **linear regression models**, i.e. Linear Regression, Ridge, Lasso and ElasticNet, as well as kNN. (check the last lab).
#
# Since we observed that somf features have very different scales, we’ll also build pipelines of all these measures with an additional scaling step. For now, we’ll stick to the default hyperparameter settings.

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error
reg = linear_model.Ridge(alpha=.5)


X_train=df[['cars_per_hour','temperature_at_2m', 'temperature_diff_2m_25m', 'wind_direction','hour_of_day']]
Y_train=df['target']

X_test=df[['cars_per_hour','temperature_at_2m', 'temperature_diff_2m_25m', 'wind_direction','hour_of_day']]
Y_test=df['target']

reg.fit(X_train, Y_train)

y_pred = reg.predict(X_test)


mse = mean_squared_error(Y_test, y_pred)
print(f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 0.3242357208080866

# %% [markdown]
# ## Exercise 1.1
# Implement 5 linear classifiers to predict the concentration of no2 from data  (predict and evaluate)

# %%
# Classifier 1
reg = linear_model.RidgeCV(alphas=np.logspace(-6, 6, 13))
reg.fit(X_train, Y_train)
y_pred = reg.predict(X_test)


mse = mean_squared_error(Y_test, y_pred)
print(f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 0.32423706293952625

# %%
# Classifier 2
reg = linear_model.LassoLars(alpha=.1)
reg.fit(X_train, Y_train)
y_pred = reg.predict(X_test)


mse = mean_squared_error(Y_test, y_pred)
print(f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 0.35642415128971766

# %%
# Classifier 3
reg = linear_model.Lasso(alpha=0.1)
reg.fit(X_train, Y_train)
y_pred = reg.predict(X_test)


mse = mean_squared_error(Y_test, y_pred)
print(f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 0.35642306223028836

# %%
# Classifier 4
reg = linear_model.BayesianRidge()
reg.fit(X_train, Y_train)
y_pred = reg.predict(X_test)


mse = mean_squared_error(Y_test, y_pred)
print(f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 0.3243022648327832

# %%
# Classifier 5
reg = linear_model.LinearRegression()
reg.fit(X_train, Y_train)
y_pred = reg.predict(X_test)


mse = mean_squared_error(Y_test, y_pred)
print(f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 0.32423527141961145

# %% [markdown]
# ## Exercise 1.2
# Implement a function below which fits each classifier passed into it on the given data, and then returns a list of the trained models.

# %%
import numpy as np

def fit_classifiers_and_return_models(X_train, Y_train):
    classifiers = [
        linear_model.RidgeCV(),
        linear_model.LassoLars(),
        linear_model.Lasso(),
        linear_model.BayesianRidge(),
        linear_model.LinearRegression(),
        KNeighborsRegressor()
    ]

    trained_models = []

    # Loop over each classifier, fit, and store the trained model
    for clf in classifiers:
        clf.fit(X_train, Y_train)
        trained_models.append(clf)

    return trained_models

trained_models = fit_classifiers_and_return_models(X_train, Y_train)
print(trained_models)
# Out:
# [RidgeCV(), LassoLars(), Lasso(), BayesianRidge(), LinearRegression(), KNeighborsRegressor()]

# %% [markdown]
# ## Exercise 1.3
# Implement a function below which evaluates each classifier passed into it on the given data, and then returns both the test score of each model. You are allowed to import additional functions from whichever module you like, but you should be able to complete the function with standard Python built-ins. Below you the function you will find example output.

# %%
def evaluate_learners(models, X_train, y_train, X_test, y_test):
    train_scores = []
    test_scores = []

    for model in models:
        model.fit(X_train, y_train)  
        
        train_scores.append(model.score(X_train, Y_train))  
        test_scores.append(model.score(X_test, Y_test))  


    return train_scores, test_scores

# %% [markdown]
# ## Exercise 1.4
# Call the function you created with a Linear Regression, Ridge, Lasso and ElasticNet, as well as kNN. Store the return values in the variables train_scores and test_scores. Then, run the code given below to produce a plot visualizing the scores.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import r2_score


trained_models = fit_classifiers_and_return_models(X_train, Y_train)

# Evaluate models
train_scores, test_scores = evaluate_learners(trained_models, X_train, Y_train, X_test, Y_test)

print("Training Scores:", train_scores)
print("Test Scores:", test_scores)
# Out:
# Training Scores: [0.42334121961704885, 0.0320592356789573, 0.03205923588694881, 0.42322525741364336, 0.4233444058526993, 0.4288464725030221]
# Test Scores: [0.42334121961704885, 0.0320592356789573, 0.03205923588694881, 0.42322525741364336, 0.4233444058526993, 0.4288464725030221]

# %%
model_names = ['RidgeCV', 'LassoLars', 'Lasso', 'BayesianRidge', 'Linear Regression', 'KNN']
x_pos = np.arange(len(model_names))

# Calculate simple error bars (e.g., using standard deviation for simplicity)
train_errors = np.std(train_scores) * np.ones_like(train_scores)
test_errors = np.std(test_scores) * np.ones_like(test_scores)

# Plotting training and test scores with error bars
plt.bar(x_pos - 0.2, train_scores, 0.4, label='Train Score', yerr=train_errors, capsize=5, color='blue', edgecolor='black')
plt.bar(x_pos + 0.2, test_scores, 0.4, label='Test Score', yerr=test_errors, capsize=5, color='red', edgecolor='black')

# Adding labels and title
plt.xticks(x_pos, model_names)
plt.xlabel('Models')
plt.ylabel('R² Score')
plt.title('Train and Test Scores with Error Bars for Different Models')
plt.legend()

# %% [markdown]
# ## Exercise 1.5
# Interpret the plot. Which is the best regressor?

# %%
#RidgeCV or BayesianRidge.Both models have high test scores, low variance, and a small train-test gap, indicating good generalization and stable performance. Lasso and LassoLars underfit, while KNN has high variance.
